# %% [markdown]
# <a href="https://colab.research.google.com/github/Haricharan-Venkatesh/exploratory-data-analysis-lab-exercises/blob/main/tutorial-question-16.07.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question_1
#Task_1
import pandas as pd
import numpy as np


np.random.seed(42)

dataset = {
    "EmployeeID": np.arange(101, 601),
    "Name": [f"Person_{i}" for i in range(1, 501)],
    "Department": np.random.choice(["HR", "IT", "Finance", "Marketing"], 500),
    "Age": np.random.randint(18, 60, 500),
    "Experience": np.random.randint(0, 40, 500),
    "Salary": np.random.randint(25000, 120001, 500),
    "Gender": np.random.choice(["Male", "Female"], 500),
    "SatisfactionScore": np.round(np.random.uniform(1, 5, 500), 2)
}

df = pd.DataFrame(dataset)


df.to_csv("employee_salary.csv", index=False)


df = pd.read_csv("employee_salary.csv")


print("First 5 Records:")
print(df.head())


print("\nLast 5 Records:")
print(df.tail())


print("\nDataset Shape:", df.shape)
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# First 5 Records:
#    EmployeeID      Name Department  Age  Experience  Salary  Gender  \
# 0         101  Person_1    Finance   38          16   60435  Female
# 1         102  Person_2  Marketing   49          12   82132    Male
# 2         103  Person_3         HR   40          19  103945    Male
# 3         104  Person_4    Finance   50          24  107050    Male
# 4         105  Person_5    Finance   20           3   27983    Male
#
#    SatisfactionScore
# 0               4.02
# 1               2.39
# 2               3.66
# 3               4.18
# 4               4.71
#
# Last 5 Records:
#      EmployeeID        Name Department  Age  Experience  Salary  Gender  \
# 495         596  Person_496    Finance   34          38  119588  Female
# 496         597  Person_497    Finance   56          16   95135  Female
# 497         598  Person_498  Marketing   39          13   60046  Female
# 498         599  Person_499         HR   43          30   72064    Male
# ...

# %%
#Task_2
import pandas as pd

df = pd.read_csv("employee_salary.csv")


print("Column Names:")
print(df.columns)


print("\nData Types:")
print(df.dtypes)


print("\nDataset Info:")
df.info()


print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# Column Names:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Experience', 'Salary',
#        'Gender', 'SatisfactionScore'],
#       dtype='object')
#
# Data Types:
# EmployeeID             int64
# Name                  object
# Department            object
# Age                    int64
# Experience             int64
# Salary                 int64
# Gender                object
# SatisfactionScore    float64
# dtype: object
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         500 non-null    int64
#  1   Name               500 non-null    object
#  2   Department         500 non-null    object
#  3   Age                500 non-null    int64
#  4   Experience         500 non-null    int64
#  5   Salary             500 non-null    int64
#  6   Gender             500 non-null    object
# ...

# %%
#Task_3
import pandas as pd

df = pd.read_csv("employee_salary.csv")


print("Missing Values in Each Column:")
print(df.isnull().sum())


print("\nPercentage of Missing Values:")
print((df.isnull().sum() / len(df)) * 100)


print("\nColumn with Highest Missing Values:")
print(df.isnull().sum().idxmax())


print("\nNumber of Duplicate Records:")
print(df.duplicated().sum())


print("\nDataset Size Before Cleaning:", len(df))


df = df.drop_duplicates()


print("Dataset Size After Cleaning:", len(df))
# Out:
# Missing Values in Each Column:
# EmployeeID           0
# Name                 0
# Department           0
# Age                  0
# Experience           0
# Salary               0
# Gender               0
# SatisfactionScore    0
# dtype: int64
#
# Percentage of Missing Values:
# EmployeeID           0.0
# Name                 0.0
# Department           0.0
# Age                  0.0
# Experience           0.0
# Salary               0.0
# Gender               0.0
# SatisfactionScore    0.0
# dtype: float64
#
# Column with Highest Missing Values:
# EmployeeID
#
# Number of Duplicate Records:
# 0
#
# Dataset Size Before Cleaning: 500
# Dataset Size After Cleaning: 500
