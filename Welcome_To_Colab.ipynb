# %% [markdown]
# <a href="https://colab.research.google.com/github/Haricharan-Venkatesh/exploratory-data-analysis-lab-exercises/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("chess_games.csv", on_bad_lines='skip')

print(df.head())
print(df.shape)
# Out:
#   game_id  rated  turns victory_status winner time_increment       white_id  \
# 0       1  FALSE     13    Out of Time  White           15+2       bourgris
# 1       2   TRUE     16         Resign  Black           5+10           a-00
# 2       3   TRUE     61           Mate  White           5+10         ischia
# 3       4   TRUE     61           Mate  White           20+0  daniamurashov
# 4       5   TRUE     95           Mate  White           30+3      nik221107
#
#    white_rating      black_id black_rating  \
# 0        1500.0          a-00         1191
# 1        1322.0     skinnerua         1261
# 2        1496.0          a-00         1500
# 3        1439.0  adivanov2009         1454
# 4        1523.0  adivanov2009         1469
#
#                                                moves opening_code  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...          D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...          B00
# ...

# %%
import pandas as pd

df = pd.read_csv("chess_games.csv", on_bad_lines="skip")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

print("\nInfo:")
print(df.info())
# Out:
# Shape: (17429, 17)
#
# Columns:
# Index(['game_id', 'rated', 'turns', 'victory_status', 'winner',
#        'time_increment', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_code', 'opening_moves',
#        'opening_fullname', 'opening_shortname', 'opening_response',
#        'opening_variation'],
#       dtype='object')
#
# Data Types:
# game_id               object
# rated                 object
# turns                  int64
# victory_status        object
# winner                object
# time_increment        object
# white_id              object
# white_rating         float64
# black_id              object
# black_rating          object
# moves                 object
# opening_code          object
# opening_moves         object
# opening_fullname      object
# opening_shortname     object
# opening_response      object
# opening_variation     object
# dtype: object
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
import pandas as pd

df = pd.read_csv("chess_games.csv", on_bad_lines="skip")

print(df.isnull().sum())
# Out:
# game_id                  0
# rated                    0
# turns                    0
# victory_status           0
# winner                   0
# time_increment           1
# white_id                 0
# white_rating             1
# black_id                 1
# black_rating             1
# moves                    1
# opening_code             2
# opening_moves            3
# opening_fullname         3
# opening_shortname        3
# opening_response     16393
# opening_variation     5030
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("chess_games.csv", on_bad_lines="skip")

print(df["winner"].value_counts())
# Out:
# winner
# White          8719
# Black          7919
# Draw            790
# Indian Game       1
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("chess_games.csv", on_bad_lines="skip")

print(df["victory_status"].value_counts())
# Out:
# victory_status
# Resign                        9590
# Mate                          5638
# Out of Time                   1448
# Draw                           752
# Indian Game: London System       1
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("chess_games.csv", on_bad_lines="skip")

high_rating = df[df["white_rating"] > 2000]

print(high_rating[["white_id", "white_rating", "winner"]].head(10))
# Out:
#                white_id  white_rating winner
# 39              rajuppi        2449.0  White
# 43              rajuppi        2443.0  White
# 48              rajuppi        2436.0  White
# 49              rajuppi        2436.0  White
# 120         chess-brahs        2036.0  Black
# 571          thebadfish        2008.0  White
# 573          thebadfish        2008.0  Black
# 575  gg_easytobeatme_yt        2100.0  White
# 579    chess_legend_rus        2068.0  White
# 581          soltan1800        2005.0  White

# %%
import pandas as pd

df = pd.read_csv("chess_games.csv", on_bad_lines="skip")

sorted_df = df.sort_values(by="white_rating", ascending=False)

print(sorted_df[["white_id", "white_rating", "winner"]].head(10))
# Out:
#           white_id  white_rating winner
# 16373  blitzbullet        2622.0  White
# 3068     lance5500        2621.0  White
# 10761    lance5500        2621.0  White
# 3071     lance5500        2621.0  White
# 10073    lance5500        2621.0  White
# 3157     lance5500        2621.0  White
# 2874     lance5500        2621.0  White
# 7167     lance5500        2621.0  White
# 12161    lance5500        2621.0  White
# 8124     lance5500        2621.0  White

# %%
import pandas as pd

df = pd.read_csv("chess_games.csv", on_bad_lines="skip")

print(df.sort_values(by="turns", ascending=False).head(10))
# Out:
#       game_id rated  turns victory_status winner time_increment  \
# 2813    13860  TRUE    349    Out of Time  White           10+0
# 5340    16387  TRUE    259           Draw   Draw           15+5
# 6936     4237  TRUE    255           Draw   Draw            7+2
# 8390    16646  TRUE    226           Draw   Draw           10+0
# 4432    15479  TRUE    222           Draw   Draw           10+0
# 8688    16944  TRUE    222           Mate  Black            9+5
# 13002    6777  TRUE    221           Draw   Draw          15+10
# 8893    17149  TRUE    212           Draw   Draw            8+0
# 10071   18327  TRUE    210           Mate  Black           10+0
# 8122     5423  TRUE    210           Mate  Black           10+0
#
#                 white_id  white_rating         black_id black_rating  \
# 2813              shiwen        2194.0            kijek         2240
# 5340            aragon26        1441.0        lone-wolf         1461
# ...
